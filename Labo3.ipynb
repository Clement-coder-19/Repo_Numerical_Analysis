# %% [markdown]
# <a href="https://colab.research.google.com/github/Clement-coder-19/Repo_Numerical_Analysis/blob/main/Labo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# I use fixed-point iteration method
def babylonian_sqrt(S, x, e, N):
    flag=False
    for step in range(N):
        if x == 0:
            print("Division by zero error!")
            return
        x_next=0.5*(x+S/x)
        print("Iteration %d, x = %0.6f"%(step+1,x_next))
        if abs(x_next-x)<e:
            x=x_next
            flag=True
            break
        x=x_next
    if flag:
      print("\nApproximate root: x:%0.6f" %(x))
    else:
      print('\nNot Convergent.')
    #I check if the result is an overestimation or not
    if x*x>S:
      print("Overestimation")
    elif x*x< S:
      print("Underestimation")
    else:
      print("Equal")



#Input
S= float(input("Enter the number to compute its square root:"))
x0 = float(input('Enter Guess: '))
e = float(input('Tolerable Error: '))
N = int(input('Maximum Step: '))

babylonian_sqrt(S, x0, e, N)
# Out:
# Enter the number to compute its square root:8
# Enter Guess: 2
# Tolerable Error: 10e-8
# Maximum Step: 100
# Iteration 1, x = 3.000000
# Iteration 2, x = 2.833333
# Iteration 3, x = 2.828431
# Iteration 4, x = 2.828427
# Iteration 5, x = 2.828427
#
# Approximate root: x:2.828427
# Underestimation
