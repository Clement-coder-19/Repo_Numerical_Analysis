# %% [markdown]
# <a href="https://colab.research.google.com/github/Clement-coder-19/MyRepo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.style.use('ggplot')

# Initial function given
def f(x):
    y = x**2 + x**3
    return y


# Definite integral of the function from a to b
def F(a,b):
    if a > b:
        raise ValueError('b must be greater than a')
    elif a == b:
        return 0
    else:
        y = (b**3-a**3)/3 + (b**4-a**4)/4
        return y

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 150, where=(ys > 150), facecolor='blue', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
